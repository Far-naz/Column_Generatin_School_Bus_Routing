# %%
import os
import pandas as pd


df = pd.read_csv('locations.csv')
df.head()
# Out:
#    LocId                               LocName       Lon       Lat  \
# 0  42812                Nav Kongsvinger Arbeid  11997062  60190993
# 1  42813        Reh. Blåkors Behandlingssenter  10655865  60542066
# 2  42815                    Øye Goksør Øyelege  11034968  59956562
# 3  42816               Kierulfs Dr Nevrologisk  10753606  59930970
# 4  42818  Tl Verpe Jostein Eidskog Tannklinikk  12121462  59985828
#
#             OnStreet                      City  ZipCode
# 0            BRUGATA  KONGSVINGER, KONGSVINGER   2212.0
# 1            BLÅKORS        EINA, VESTRE TOTEN   2843.0
# 2          DEPOTGATA       LILLESTRØM, SKEDSMO   2000.0
# 3    CLAUS RIIS GATE                OSLO, OSLO    457.0
# 4  DR. LUNDERBYS VEG        SKOTTERUD, EIDSKOG   2230.0

# %%
df_filtered = df[df["LocId"] == 33337]
df_filtered.iloc[0]['Lat']
# Out:
# 61124656
